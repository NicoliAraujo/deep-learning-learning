# %%
import pandas as pd

# %%
df = pd.read_csv('/home/nicoli/github/ssd_keras/dataset/csv/imdb_csv/imdb.csv', index_col=0)

# %%
df
# Out:
#            dob  photo_taken  \
# 0       693726         1968
# 1       693726         1970
# 2       693726         1968
# 3       693726         1968
# 4       693726         1968
# 5       702986         1991
# 6       702986         2004
# 7       702986         2004
# 8       702986         1991
# 9       702986         2004
# 10      702986         2008
# 11      702986         1991
# 12      702986         1974
# 13      702986         2007
# 14      702986         1974
# 15      702986         2006
# 16      702986         2006
# 17      702986         2006
# 18      702986         2006
# 19      702986         2004
# 20      702986         1988
# 21      702986         2004
# 22      702986         1974
# 23      702986         2007
# 24      702986         1974
# 25      702986         2005
# 26      702986         2007
# 27      702986         2007
# 28      702986         2005
# 29      702986         2008
# ...        ...          ...
# 391167  726831         2011
# ...
