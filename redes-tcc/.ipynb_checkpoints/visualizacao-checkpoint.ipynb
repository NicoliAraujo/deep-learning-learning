# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df_dirty = pd.read_csv('/home/nicoli/github/ssd_keras/dataset/csv/imdb_csv/imdb.csv', index_col=0)
df_clean = pd.read_csv('/home/nicoli/github/ssd_keras/dataset/csv/imdb_csv/imdb_clean.csv', index_col=0)

# %%
df_dirty.shape, df_clean.shape
# Out:
# ((460723, 13), (47950, 12))

# %%
sns.set_style("ticks")

# %%
df_dirty.groupby('celeb_id').size().loc[df_dirty.groupby('celeb_id').size()>700]
df_dirty.groupby('celeb_id').size().describe()
# Out:
# celeb_id
# 1096     795
# 2336     818
# 4036     787
# 8811     827
# 14420    719
# 14588    719
# 16352    739
# 19084    779
# 20250    703
# dtype: int64
# count    20284.000000
# mean        22.713617
# std         56.158003
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         16.000000
# max        827.000000
# dtype: float64

# %%
df_clean.groupby('celeb_id').size().describe()
# Out:
# count    14607.000000
# mean         3.282673
# std          3.712227
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max         38.000000
# dtype: float64

# %%
#bins = df_dirty.groupby('celeb_id').size().size
fig1, ax1 = plt.subplots()
df_dirty['celeb_id'].plot(kind='hist', x=df_dirty['celeb_id'], bins=20284, color='black', title=None, ax=ax1)
ax1.set_xlabel("ID Celebridade")
ax1.set_ylabel("Quantidade")
fig1.savefig("/home/nicoli/github/nicoli-tcc/imagens/celeb_id_hist_old.png")
# Out:
# Text(0.5,0,'ID Celebridade')
# Text(0,0.5,'Quantidade')

# %%
bins_clean = df_clean.groupby('celeb_id').size().size
fig2, ax2 = plt.subplots()
df_clean['celeb_id'].plot(kind='hist', bins=bins_clean, color='black', title=None, ax=ax2)
ax2.set_xlabel("ID Celebridade")
ax2.set_ylabel("Quantidade")
fig2.savefig("/home/nicoli/github/nicoli-tcc/imagens/celeb_id_hist_clean.png")
# Out:
# Text(0.5,0,'ID Celebridade')
# Text(0,0.5,'Quantidade')

# %%
df_clean[df_clean.age<0]
# Out:
# Empty DataFrame
# Columns: [celeb_id, name, full_path, face_score, second_face_score, xmin, xmax, ymin, ymax, dob_date, photo_taken, age, gender]
# Index: []

# %%
bins_clean = df_clean.groupby('age').size().size
fig2, ax2 = plt.subplots()
ax2 = sns.distplot(df_clean['age'], bins=bins_clean, kde=False, color='black')

ax2.set_xlabel("Idade")
ax2.set_ylabel("Quantidade")
fig2.savefig("/home/nicoli/github/nicoli-tcc/imagens/idade_hist_clean.png")
# Out:
# Text(0.5,0,'Idade')
# Text(0,0.5,'Quantidade')

# %%
bins = df_dirty.groupby('age').size().size
fig1, ax1 = plt.subplots()
ax1 = sns.distplot(df_dirty['age'], bins=bins, kde=False, color='black')
ax2.set_xlabel("Idade")
ax2.set_ylabel("Quantidade")
fig2.savefig("/home/nicoli/github/nicoli-tcc/imagens/idade_hist_old.png")
# Out:
# Text(0.5,16.2,'Idade')
# Text(16.2,0.5,'Quantidade')

# %%
g = sns.FacetGrid(df_clean_50, row="gender", col="age", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "celeb_id", color="steelblue", bins=bins, lw=0)

# %%
df_clean.head()
# Out:
#         celeb_id                 name  \
# 327194         2  'Weird Al' Yankovic
# 327184         2  'Weird Al' Yankovic
# 327189         2  'Weird Al' Yankovic
# 327174         2  'Weird Al' Yankovic
# 417707         3             2 Chainz
#
#                                                 full_path  face_score  \
# 327194  imdb/48/nm0946148_rm922142208_1959-10-23_2014.jpg    2.533124
# 327184  imdb/48/nm0946148_rm3125254656_1959-10-23_1989...    2.431079
# 327189  imdb/48/nm0946148_rm3591961856_1959-10-23_2015...    3.570310
# 327174  imdb/48/nm0946148_rm1179500032_1959-10-23_2011...    1.685582
# 417707  imdb/61/nm5183361_rm1478883584_1977-9-12_2014.jpg    3.495802
#
#               xmin        xmax        ymin       ymax    dob_date  \
# 327194  624.640000  917.504000  165.888000  458.75200  1959-10-23
# 327184   62.775397  174.231111   75.220476  186.67619  1959-10-23
# 327189  477.661987  864.752704  607.374893  994.46561  1959-10-23
# ...
