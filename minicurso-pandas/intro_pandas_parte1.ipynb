# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ks_proj2018 = pd.read_csv('ks-projects-201801-v2.csv', index_col=0)

# %% [markdown]
# ## Métodos de Visualização dos Dados

# %%
ks_proj2018.head()
# Out:
#                                                          name        category  \
# ID
# 1000002330                    The Songs of Adelaide & Abullah          Poetry
# 1000003930      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 1000004038                                     Where is Hank?  Narrative Film
# 1000007540  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 1000011046  Community Film Project: The Art of Neighborhoo...    Film & Video
#
#            main_category currency    deadline     goal             launched  \
# ID
# 1000002330    Publishing      GBP  2015-10-09   1000.0  2015-08-11 12:12:28
# 1000003930  Film & Video      USD  2017-11-01  30000.0  2017-09-02 04:43:57
# 1000004038  Film & Video      USD  2013-02-26  45000.0  2013-01-12 00:20:50
# 1000007540         Music      USD  2012-04-16   5000.0  2012-03-17 03:24:11
# 1000011046  Film & Video      USD  2015-08-29  19500.0  2015-07-04 08:35:03
#
# ...

# %%
ks_proj2018.select_dtypes(include=[np.number]).head()
# Out:
#                goal  pledged  backers  usd pledged  usd_pledged_real  \
# ID
# 1000002330   1000.0      0.0        0          0.0               0.0
# 1000003930  30000.0   2421.0       15        100.0            2421.0
# 1000004038  45000.0    220.0        3        220.0             220.0
# 1000007540   5000.0      1.0        1          1.0               1.0
# 1000011046  19500.0   1283.0       14       1283.0            1283.0
#
#             usd_goal_real
# ID
# 1000002330        1533.95
# 1000003930       30000.00
# 1000004038       45000.00
# 1000007540        5000.00
# 1000011046       19500.00

# %%
numeric_columns = ks_proj2018.select_dtypes(include=[np.number]).columns
numeric_columns
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged', 'usd_pledged_real',
#        'usd_goal_real'],
#       dtype='object')

# %%
string_columns = ks_proj2018.select_dtypes(include=[np.object]).columns
string_columns
# Out:
# Index(['name', 'category', 'main_category', 'currency', 'deadline', 'launched',
#        'state', 'country'],
#       dtype='object')

# %%
print('Média\n', ks_proj2018[numeric_columns].mean(), 
      '\n\nDesvio Padrão\n', ks_proj2018[numeric_columns].std(), 
      '\n\nValor máximo\n', ks_proj2018[numeric_columns].max(), 
      '\n\nValor Mínimo\n',ks_proj2018[numeric_columns].min())
# Out:
# Média
#  goal                49522.988841
# pledged              9750.538301
# backers               106.688366
# usd pledged          7036.802252
# usd_pledged_real     9120.898549
# usd_goal_real       45863.025972
# dtype: float64
#
# Desvio Padrão
#  goal                1.189362e+06
# pledged             9.601094e+04
# backers             9.117101e+02
# usd pledged         7.864016e+04
# usd_pledged_real    9.131969e+04
# usd_goal_real       1.158767e+06
# dtype: float64
#
# Valor máximo
#  goal                1.000000e+08
# pledged             2.033899e+07
# backers             2.193820e+05
# usd pledged         2.033899e+07
# usd_pledged_real    2.033899e+07
# usd_goal_real       1.663614e+08
# dtype: float64
#
# Valor Mínimo
#  goal                0.01
# pledged             0.00
# backers             0.00
# usd pledged         0.00
# usd_pledged_real    0.00
# usd_goal_real       0.01
# dtype: float64

# %%
ks_proj2018.describe()
# Out:
#                goal       pledged        backers   usd pledged  \
# count  3.748600e+05  3.748600e+05  374860.000000  3.748600e+05
# mean   4.952299e+04  9.750538e+03     106.688366  7.036802e+03
# std    1.189362e+06  9.601094e+04     911.710124  7.864016e+04
# min    1.000000e-02  0.000000e+00       0.000000  0.000000e+00
# 25%    2.000000e+03  3.100000e+01       2.000000  1.698000e+01
# 50%    5.500000e+03  6.200000e+02      12.000000  3.947650e+02
# 75%    1.650000e+04  4.080000e+03      57.000000  3.034425e+03
# max    1.000000e+08  2.033899e+07  219382.000000  2.033899e+07
#
#        usd_pledged_real  usd_goal_real
# count      3.748600e+05   3.748600e+05
# mean       9.120899e+03   4.586303e+04
# std        9.131969e+04   1.158767e+06
# min        0.000000e+00   1.000000e-02
# 25%        3.100000e+01   2.000000e+03
# 50%        6.244950e+02   5.500000e+03
# 75%        4.050895e+03   1.600000e+04
# max        2.033899e+07   1.663614e+08

# %%
ks_proj2018.index
# Out:
# Int64Index([1000002330, 1000003930, 1000004038, 1000007540, 1000011046,
#             1000014025, 1000023410, 1000030581, 1000034518,  100004195,
#             ...
#              999969812,  999971898,  999972264,  999975836,  999976312,
#              999976400,  999977640,  999986353,  999987933,  999988282],
#            dtype='int64', name='ID', length=374860)

# %%
ks_proj2018.columns
# Out:
# Index(['name', 'category', 'main_category', 'currency', 'deadline', 'goal',
#        'launched', 'pledged', 'state', 'backers', 'country', 'usd pledged',
#        'usd_pledged_real', 'usd_goal_real'],
#       dtype='object')

# %%
ks_proj2018.shape
# Out:
# (374860, 14)

# %%
ks_proj2018.T
# Out:
# ID                                     1000002330  \
# name              The Songs of Adelaide & Abullah
# category                                   Poetry
# main_category                          Publishing
# currency                                      GBP
# deadline                               2015-10-09
# goal                                         1000
# launched                      2015-08-11 12:12:28
# pledged                                         0
# state                                      failed
# backers                                         0
# country                                        GB
# usd pledged                                     0
# usd_pledged_real                                0
# usd_goal_real                             1533.95
#
# ID                                                   1000003930  \
# name              Greeting From Earth: ZGAC Arts Capsule For ET
# category                                         Narrative Film
# ...

# %%
### Verifique o formato do dataset transposto

# %%
### Verififique apenas os 5 primeiros itens do dataset transposto

# %%
ks_proj2018.sort_values(by='launched', ascending=False)
# Out:
#                                                          name  \
# ID
# 1339173863                              Spirits of the Forest
# 1830173355                                Digital Dagger Coin
# 2106246194    Help save La Gattara, Arizona's first Cat Cafe!
# 974738310   EVO Planner: The World's First Personalized Fl...
# 1486845240                  Americas Got Talent - Serious MAK
# 150815475                             Carl Sagan Quote Prints
# 473911584                      A New Miss Eaves EP (& Videos)
# 80324970       T.P.Customs, traditionally Handcrafted guitars
# 272668251                              Forge In YOUR OWN Fire
# 163752222         Printable Tabletop Terrain for Ancient Rome
# 462436087                    Charlie Chimps Curious Creatures
# 754894401                        Spring Breakdown The Feature
# 35294140                         Fantasy Football Goblin Dice
# 712099998   The Final Clause of Tacitus - Not Like The Res...
# ...

# %%
### Ordene o dataset pela coluna 'name'

# %%
ks_proj2018.sort_index()
# Out:
#                                                          name  \
# ID
# 5971                    An American Apocalypse: The Reckoning
# 18520                                      Grandma's are Life
# 21109                                                    Meta
# 21371                                       Water Powered Car
# 24380       Puss N' Books: A relaxing cat cafe and bookstore.
# 33867                                 TASTE MAKERS BY TRISH P
# 39036                               The Meat Candy Experience
# 39409                                   WHILE THE TREES SLEEP
# 46588       Orage: Interactive Lightning Experience at Bur...
# 48139       Employee evaluation and performance management...
# 50831                                    The Gettysburg Story
# 52687                                 Revenge of the Platypus
# 53154                                     Swim (Feature Film)
# 56833                                          Abilities Rock
# ...

# %%
ks_proj2018.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Seleção

# %% [markdown]
# #### Utilizando métodos da biblioteca numpy

# %%
ks_proj2018['name'].head()
# Out:
# 0                      The Songs of Adelaide & Abullah
# 1        Greeting From Earth: ZGAC Arts Capsule For ET
# 2                                       Where is Hank?
# 3    ToshiCapital Rekordz Needs Help to Complete Album
# 4    Community Film Project: The Art of Neighborhoo...
# Name: name, dtype: object

# %%
### Selecionae a coluna 'pledged'

# %%
ks_proj2018['name'][0]
# Out:
# 'The Songs of Adelaide & Abullah'

# %% [markdown]
# #### Utilizando métodos da biblioteca pandas

# %%
ks_proj2018.loc[:,'name'].head()
# Out:
# 0                      The Songs of Adelaide & Abullah
# 1        Greeting From Earth: ZGAC Arts Capsule For ET
# 2                                       Where is Hank?
# 3    ToshiCapital Rekordz Needs Help to Complete Album
# 4    Community Film Project: The Art of Neighborhoo...
# Name: name, dtype: object

# %%
ks_proj2018.loc[:,['name', 'category']].head()
# Out:
#                                                 name        category
# 0                    The Songs of Adelaide & Abullah          Poetry
# 1      Greeting From Earth: ZGAC Arts Capsule For ET  Narrative Film
# 2                                     Where is Hank?  Narrative Film
# 3  ToshiCapital Rekordz Needs Help to Complete Album           Music
# 4  Community Film Project: The Art of Neighborhoo...    Film & Video

# %%
ks_proj2018.loc[14:29,'main_category':'backers'].head()
# Out:
#    main_category currency    deadline    goal             launched  pledged  \
# 14         Games      GBP  2017-05-03  5000.0  2017-04-05 19:44:18  94175.0
# 15        Design      USD  2015-02-28  2500.0  2015-01-29 02:10:53    664.0
# 16        Comics      USD  2014-11-08  1500.0  2014-10-09 22:27:52    395.0
# 17    Publishing      USD  2015-05-10  3000.0  2015-04-10 21:20:54    789.0
# 18         Music      USD  2012-08-17   250.0  2012-08-02 14:11:32    250.0
#
#          state  backers
# 14  successful      761
# 15      failed       11
# 16      failed       16
# 17      failed       20
# 18  successful        7

# %%
ks_proj2018[ks_proj2018.loc[:,'pledged']>500000]
# Out:
#                                                      name         category  \
# 174                Air Bonsai | Create your "little star"   Product Design
# 328                Pimax: The World's First 8K VR Headset         Hardware
# 639     QUARTZ Bottle - Water Purification in a Self-C...       Technology
# 869                                  UNDIVE DARK SEA 500m   Product Design
# 922            Moment: Make Your iPhone 7 A Better Camera   Product Design
# 948     Qi Aerista: The Ultimate Wi-Fi-Enabled Smart T...   Product Design
# 1569    The Electron: Cellular dev kit with a global d...  DIY Electronics
# 1703    NORTH DRINKWARE : Mt. Hood, The Oregon Pint Glass   Product Design
# 1854    Redefining Italian Luxury Watches - Filippo Lo...           Design
# 2187        GINA: Smart coffee instrument / by GOAT STORY   Product Design
# 2299    que Bottle: The Fashionable & Collapsible Trav...   Product Design
# ...

# %% [markdown]
# ## Apply

# %%
ks_proj2018[numeric_columns].apply(lambda coluna: coluna.max() - coluna.min())
# Out:
# goal                1.000000e+08
# pledged             2.033899e+07
# backers             2.193820e+05
# usd pledged         2.033899e+07
# usd_pledged_real    2.033899e+07
# usd_goal_real       1.663614e+08
# dtype: float64

# %% [markdown]
# #### Padronizando a coluna 'name'

# %%
ks_proj2018.sort_values(by='name', inplace=True)
ks_proj2018
# Out:
#                                                      name          category  \
# 219335                      IT’S A HOT CAPPUCCINO NIGHT             Fiction
# 330404               "Pastriology": a global documentary        Documentary
# 127373              15   A Feature Length Film (Canceled)    Narrative Film
# 68142            "A Fine Mess." A Television Sitcom Pilot            Shorts
# 31230        "A TERRIBLE LIE," a new play by Jim Reyland            Theater
# 64187    "Done With Error's," new EdGeR album and Film...              Rock
# 271672                        "Gimme Five" for high five!           Theater
# 226722                                 "Go the Right Way"           Hip-Hop
# 64185                     "IdEgo" 20th anniversary season             Dance
# 154222                     "Me and My Old Man"  Webseries         Webseries
# 174940   "Miss Julie & The Stronger": Sexy, raucous, i...           Theater
# ...

# %%
ks_proj2018.loc[:,string_columns] = ks_proj2018[string_columns].apply(lambda coluna: coluna.str.replace('\"', ''))

ks_proj2018[string_columns].head()
# Out:
#                                                name        category  \
# 219335                IT’S A HOT CAPPUCCINO NIGHT           Fiction
# 330404           Pastriology: a global documentary      Documentary
# 127373        15   A Feature Length Film (Canceled)  Narrative Film
# 68142        A Fine Mess. A Television Sitcom Pilot          Shorts
# 31230    A TERRIBLE LIE, a new play by Jim Reyland          Theater
#
#        main_category currency    deadline             launched     state  \
# 219335    Publishing      USD  2010-12-05  2010-11-04 23:46:07    failed
# 330404  Film & Video      USD  2011-01-01  2010-11-25 06:28:55    failed
# 127373  Film & Video      USD  2011-05-12  2011-04-11 06:44:40  canceled
# 68142   Film & Video      USD  2009-12-15  2009-11-04 22:31:44    failed
# 31230        Theater      USD  2010-10-15  2010-08-18 17:20:54    failed
#
#        country
# 219335      US
# 330404      US
# 127373      US
# 68142       US
# 31230       US

# %%
### SUA VEZ!
### Mude todas as strings para iniciarem com letra maiúscula (função capitalize())

# %% [markdown]
# ### Dados categóricos

# %%
categorical_columns = ['main_category', 'currency', 'state', 'country']
ks_proj2018[categorical_columns] = ks_proj2018[categorical_columns].apply(lambda coluna: coluna.astype("category"))

# %%
ks_proj2018['main_category'].cat.categories

# %%
ks_proj2018['state'].cat.categories

# %%
ks_proj2018['state'] = ks_proj2018['state'].cat.set_categories(['canceled', 'failed', 'suspended','live', 'successful'])

# %%
ks_proj2018.sort_values(by='state', ascending=False).head()

# %% [markdown]
# ### Agrupamento

# %%
ks_proj2018.groupby('state').size()
# Out:
# state
# canceled       38757
# failed        197611
# live            2798
# successful    133851
# suspended       1843
# dtype: int64

# %%
ks_proj2018.groupby('state').mean()
# Out:
#                      goal       pledged     backers   usd pledged  \
# state
# canceled     86233.109687   2646.515938   26.002142   1875.463782
# failed       67363.127949   1427.445891   16.431236   1133.755014
# live         76780.893138   9088.487545   68.124017   1254.124725
# successful   10166.109761  24094.387965  264.128397  17356.034449
# suspended   181648.937059  10824.334031  105.253391   7842.795621
#
#             usd_pledged_real  usd_goal_real
# state
# canceled         2341.025367   75613.449092
# failed           1321.102821   63189.222623
# live             5871.264482   62548.695954
# successful      22664.485818    9535.701785
# suspended        9317.727146  175476.682919

# %%
ks_proj2018.groupby('state').std()
# Out:
#                     goal        pledged      backers    usd pledged  \
# state
# canceled    1.470467e+06   17008.028373   136.103931   10186.283673
# failed      1.447613e+06    9566.886024    71.242563    6221.699798
# live        1.885737e+06   52016.927543   382.621884    6836.491276
# successful  3.125570e+04  158355.665771  1505.152003  130122.808179
# suspended   3.450074e+06  101408.963272   751.124406   98364.276285
#
#             usd_pledged_real  usd_goal_real
# state
# canceled        13527.499146   1.281752e+06
# failed           6822.053917   1.436066e+06
# live            31435.985467   1.875803e+06
# successful     150963.061319   2.796708e+04
# suspended       99394.127749   3.447346e+06

# %%
pd.set_option('display.max_columns', 500)
ks_proj2018.groupby('state').describe().T
# Out:
# state                       canceled        failed          live  \
# backers          count  3.875700e+04  1.976110e+05  2.798000e+03
#                  mean   2.600214e+01  1.643124e+01  6.812402e+01
#                  std    1.361039e+02  7.124256e+01  3.826219e+02
#                  min    0.000000e+00  0.000000e+00  0.000000e+00
#                  25%    0.000000e+00  1.000000e+00  1.000000e+00
#                  50%    3.000000e+00  3.000000e+00  5.000000e+00
#                  75%    1.500000e+01  1.200000e+01  2.600000e+01
#                  max    9.326000e+03  6.550000e+03  1.074800e+04
# goal             count  3.875700e+04  1.976110e+05  2.798000e+03
#                  mean   8.623311e+04  6.736313e+04  7.678089e+04
#                  std    1.470467e+06  1.447613e+06  1.885737e+06
#                  min    1.000000e-02  1.500000e-01  1.000000e+00
#                  25%    3.300000e+03  2.500000e+03  2.350000e+03
# ...

# %%
### Sua vez! Agrupe pelo país e mostre a quantidade de exemplos

# %%
ks_proj2018[numeric_columns].corr()
# Out:
#                       goal   pledged   backers  usd pledged  usd_pledged_real  \
# goal              1.000000  0.007327  0.003969     0.005534          0.005072
# pledged           0.007327  1.000000  0.717858     0.857370          0.952736
# backers           0.003969  0.717858  1.000000     0.697426          0.753449
# usd pledged       0.005534  0.857370  0.697426     1.000000          0.907743
# usd_pledged_real  0.005072  0.952736  0.753449     0.907743          1.000000
# usd_goal_real     0.942691  0.004992  0.004476     0.006172          0.005566
#
#                   usd_goal_real
# goal                   0.942691
# pledged                0.004992
# backers                0.004476
# usd pledged            0.006172
# usd_pledged_real       0.005566
# usd_goal_real          1.000000

# %% [markdown]
# ## Gráficos
